# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Get the MNIST Training and testing set
mnist_train = datasets.MNIST("./data", train=True, download=True, transform=transforms.ToTensor())
mnist_test = datasets.MNIST("./data", train=False, download=True, transform=transforms.ToTensor())

# Only consider 0/1 examples.
train_idx = mnist_train.targets <= 1
mnist_train.data = mnist_train.data[train_idx]
mnist_train.targets = mnist_train.targets[train_idx]

test_idx = mnist_test.test_labels <= 1
mnist_test.data = mnist_test.data[test_idx]
mnist_test.targets = mnist_test.targets[test_idx]

# Use the DataLoader to load batch in the form of batches
train_loader = DataLoader(mnist_train, batch_size = 100, shuffle=True)
test_loader = DataLoader(mnist_test, batch_size = 100, shuffle=False)

# do a single pass over the data
def epoch(loader, model, opt=None):
    total_loss, total_err = 0.,0.
    for X,y in loader:
        yp = model(X.view(X.shape[0], -1))[:,0]
        loss = nn.BCEWithLogitsLoss()(yp, y.float())
        if opt:
            opt.zero_grad()
            loss.backward()
            opt.step()

        total_err += ((yp > 0) * (y==0) + (yp < 0) * (y==1)).sum().item()
        total_loss += loss.item() * X.shape[0]
    return total_err / len(loader.dataset), total_loss / len(loader.dataset)

# %%
# Build a simple linear classifier and train it
model = nn.Linear(784, 1)
opt = optim.SGD(model.parameters(), lr=1.)
print("Train Err", "Train Loss", "Test Err", "Test Loss", sep="\t")
for i in range(10):
    train_err, train_loss = epoch(train_loader, model, opt)
    test_err, test_loss = epoch(test_loader, model)
    print(*("{:.6f}".format(i) for i in (train_err, train_loss, test_err, test_loss)), sep="\t")

X_test = (test_loader.dataset.test_data.float()/255).view(len(test_loader.dataset),-1)
y_test = test_loader.dataset.test_labels
yp = model(X_test)[:,0]
idx = (yp > 0) * (y_test == 0) + (yp < 0) * (y_test == 1)
plt.imshow(1-X_test[idx][0].view(28,28).numpy(), cmap="gray")
plt.title("Wrongly predicted image")
#plt.title("True Label: {}".format(y_test[idx].item()))
# Out:
# Train Err	Train Loss	Test Err	Test Loss
# 0.007975	0.015347	0.000946	0.003213
# 0.001342	0.005265	0.000473	0.002490
# 0.001500	0.004350	0.000473	0.002310
# 0.001105	0.003830	0.000473	0.002212
# 0.000947	0.003504	0.000473	0.002035
# 0.000790	0.003053	0.000946	0.002256
# 0.001105	0.003032	0.000946	0.001968
# 0.000790	0.002814	0.000473	0.001929
# 0.000790	0.002630	0.000473	0.001866
# 0.000711	0.002499	0.000473	0.001871
# Text(0.5, 1.0, 'Wrongly predicted image')

# %%
# For the linear binary classifier case, we see that the optimal perturbation: -y*epsilon*.sign(weights) 
# is same for all the examples.
epsilon = 0.2
delta = epsilon * model.weight.detach().sign().view(28,28) # Without the negative sign here and we should multiply with 'y' as well later on for the linear case
plt.imshow(1-delta.numpy(), cmap="gray")

"""
By careful observation we notice the perturbation has a 1 (with black pixels) at the center and 
0 (or curves to be precise with white pixels ) around the center
The intuition here is that moving in the black direction, we make the classifier think the image is more like a 1,
while moving in the white direction, more like a 0. 
"""

# %%
# A function to test accuracy when we add adversarial attack on the test set
def epoch_adv(loader, model, delta):
    total_loss, total_err = 0.,0.
    for X,y in loader:
        # To add the adversarial attack, we actually subtract it here in this case and
        # Replace y with (2*y - 1) to get range from -1 to 1
        yp = model((X-(2*y.float()[:,None,None,None]-1)*delta).view(X.shape[0], -1))[:,0]
        loss = nn.BCEWithLogitsLoss()(yp, y.float())
        total_err += ((yp > 0) * (y==0) + (yp < 0) * (y==1)).sum().item()
        total_loss += loss.item() * X.shape[0]
    return total_err / len(loader.dataset), total_loss / len(loader.dataset)
print(epoch_adv(test_loader, model, delta[None,None,:,:]))
# Out:
# (0.8241134751773049, 3.282969851302199)

# %%
# Plot the adversarial examples
f,ax = plt.subplots(5,5, sharey=True)
for i in range(25):
    # adversarial example = input imaage + delta. The delta calculated previously is the magnitude and to consider
    # sign, we perform few calculations. (2y -1 scales 0/1 entries to -1/+1) 
    ax[i%5][i//5].imshow(1-(X_test[i].view(28,28) - (2*y_test[i]-1)*delta).numpy(), cmap="gray") 
    ax

# %%
# A function that performs robust training
def epoch_robust(loader, model, epsilon, opt=None):
    total_loss, total_err = 0.,0.
    for X,y in loader:
        yp = model(X.view(X.shape[0], -1))[:,0] - epsilon*(2*y.float()-1)*model.weight.norm(1)
        loss = nn.BCEWithLogitsLoss()(yp, y.float())
        if opt:
            opt.zero_grad()
            loss.backward()
            opt.step()
        
        total_err += ((yp > 0) * (y==0) + (yp < 0) * (y==1)).sum().item()
        total_loss += loss.item() * X.shape[0]
    return total_err / len(loader.dataset), total_loss / len(loader.dataset)

model = nn.Linear(784, 1)
opt = optim.SGD(model.parameters(), lr=1e-1)
epsilon = 0.2
print("Rob. Train Err", "Rob. Train Loss", "Rob. Test Err", "Rob. Test Loss", sep="\t")
for i in range(20):
    train_err, train_loss = epoch_robust(train_loader, model, epsilon, opt)
    test_err, test_loss = epoch_robust(test_loader, model, epsilon)
    print(*("{:.6f}".format(i) for i in (train_err, train_loss, test_err, test_loss)), sep="\t")
# Out:
# Rob. Train Err	Rob. Train Loss	Rob. Test Err	Rob. Test Loss
# 0.149783	0.377422	0.062411	0.201320
# 0.073036	0.222943	0.053428	0.171884
# 0.063166	0.196841	0.050118	0.160551
# 0.056850	0.183419	0.040189	0.142901
# 0.052507	0.174161	0.036879	0.135029
# 0.050296	0.167936	0.035934	0.133577
# 0.047375	0.162503	0.032624	0.121863
# 0.046506	0.157965	0.029787	0.120681
# 0.044295	0.154488	0.030733	0.118687
# 0.042874	0.151547	0.028369	0.119377
# 0.041453	0.148837	0.027423	0.110654
# 0.040111	0.146805	0.026950	0.107248
# 0.039163	0.145007	0.028842	0.114416
# 0.037821	0.143016	0.026478	0.105980
# 0.037742	0.141503	0.026950	0.108842
# 0.036794	0.140220	0.026478	0.108700
# 0.036873	0.139222	0.024586	0.100899
# 0.035926	0.138030	0.025059	0.104462
# 0.034741	0.136925	0.024113	0.102721
# 0.033478	0.136060	0.024586	0.100905

# %%
train_err, train_loss = epoch(train_loader, model)
test_err, test_loss = epoch(test_loader, model)
print("Train Err", "Train Loss", "Test Err", "Test Loss", sep="\t")
print(*("{:.6f}".format(i) for i in (train_err, train_loss, test_err, test_loss)), sep="\t")
# Out:
# Train Err	Train Loss	Test Err	Test Loss
# 0.006080	0.015429	0.003310	0.008326

# %%
delta = -epsilon * model.weight.detach().sign().view(28,28)
plt.imshow(delta.numpy(), cmap="gray")
